# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
query_words = {'ciberseguridad', 'seguridad informatica', 'filtran datos', 'sitio web', 'cibercrimen'}

key_words = {}


def make_url(page, search_string):
    """ Creates a url, querying prensalibre for the given search_string on a given page.
    Pages start on 1, ends on code 404
    parameters:
        page(int): number of page
        search_string(str): query string to be used
    returns:
        str: resulting url
    """

    query_string = str(search_string).replace(" ", "+") 
    return f"https://www.prensalibre.com/page/{str(page)}/?s={query_string}"

# https://www.prensalibre.com/?s=

def crawler(query_words:set, key_words:set, limit = 1): 
    """
    main(): iterar sobre la pagina principal.
            recibir el resultado de make_url.
    parameters: 
        limit(int): limit of pages per query
        query_words(set): words to be queried on the web page
        key_words(set): key words to be searched inside the page results
    returns:
        pd.DataFrame: important data 
        
    """
    queries_urls = []
    
    for query_word in query_words:
        page_num = 0 
        while(True):
            page_num+=1
            if limit < page_num:
                break
            raw=requests.get(make_url(page_num, query_word))
            html=raw.text
            response_status = raw.status_code
            if response_status == 404 or response_status == '404':
                break
            
            bs4= BeautifulSoup(html,"html.parser")
            results = get_results(bs4)
            queries_urls.extend(results)
    print(queries_urls)
    data = []
    for url in queries_urls:
        raw=requests.get(url)
        html=raw.text
        response_status = raw.status_code
        if response_status == 404 or response_status == '404':
            next
        bs4= BeautifulSoup(html,"html.parser")
        page_data = analyse_page(bs4)
        page_data['html'] = html # this is to add html to the pandas dataframe
        data.append(page_data)
    df = pd.DataFrame(data)
    # print(df.head(2))
        
        
    return df
            #analyse_page(bs4, key_words)
            
            

def get_results(soups):
    """ gets the results list from a html
    parameters:
        bs4(BeautifulSoup): html of the prensalibre query webpage
    returns:
        list: list containing the url
    """
    result_list = []
    bs4= soups
    
    h1= str(bs4.select("h1", { 'class': 'story-title'}))
    h1 = BeautifulSoup(h1)
    a_type= h1.find_all("a")
    for link in a_type:
        result_list.append(link.get('href'))

    return(result_list)

def analyse_page(html_soup):
    """
    Searches for instances of keywords
    parameters:
        bs4(BeautifulSoup): html of the prensalibre single new webpage
    returns:
        dict: publishing date, author, and tags archive listings.
    """
    # fecha de publicación
    publishing_date = html_soup.find("time")
    if publishing_date: publishing_date = publishing_date.get("datetime")
    author = html_soup.find("span", {'class':'author vcard'})
    if author: author = author.text
    tags = html_soup.find("div", {'class': 'tag-list-podcast'})
    if tags: tags_archive = [t.text.upper() for t in tags.findAll('a')]
    else: tags_archive = []
    for element in {'plus-title', 'sart-title'}:
        title = html_soup.find("h1", {"class":element})
        if title: break
    return {"publishing_date":publishing_date,"author":author,"tags_archive":tags_archive, "title":title}
    
    

if __name__ == '__main__':
teca-de-periodismo-y-organizaciones-rechazan-ley-contra-la-ciberdelincuencia/', 'https://www.prensalibre.com/vida/tecnologia/ciberseguridad-personal-consejos-para-despistados/', 'https://www.prensalibre.com/vida/tecnologia/puede-la-invasion-de-ucrania-intensificar-la-ciberguerra/', 'https://www.prensalibre.com/pl-plus/vida/las-aplicaciones-de-citas-el-nuevo-blanco-de-los-criptoestafadores/', 'https://www.prensalibre.com/guatemala/justicia/redes-sociales-la-nueva-modalidad-con-la-que-pandilleros-reclutan-a-menores-de-edad-en-guatemala-breaking/', 'https://www.prensalibre.com/guatemala/justicia/los-estafadores-que-se-hacen-pasar-por-empresas-que-envian-paquetes/', 'https://www.prensalibre.com/pl-plus/guatemala/politica/asi-funciona-la-comision-presidencial-por-la-paz-y-los-derechos-humanos/', 'https://www.prensalibre.com/guatemala/justicia/fraudes-y-estafas-se-incrementaron-durante-la-pandemia/', 'https://www.prensalibre.com/internacional/asi-desmantelaron-la-tienda-en-internet-mas-grande-del-mundo-que-vendian-drogas-documentos-y-divisas-falsas/', 'https://www.prensalibre.com/internacional/hackers-atacan-cadena-de-distribucion-de-vacunas-para-coronavirus/', 'https://www.prensalibre.com/economia/lavado-de-dinero-proponen-vigilar-mas-de-cerca-a-videoloterias-casinos-y-empresas-que-reciben-remesas/', 'https://www.prensalibre.com/economia/coronavirus-estos-son-los-delitos-para-lavar-dinero-que-se-dispararon-por-la-pandemia/', 'https://www.prensalibre.com/vida/tecnologia/troyanos-bancario ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [1], line 115
#     110     return {"publishing_date":publishing_date,"author":author,"tags_archive":tags_archive, "title":title}
#     114 if __name__ == '__main__':
# --> 115     df = crawler(query_words=query_words, key_words=key_words, limit = 10)
#
# Cell In [1], line 62, in crawler(query_words, key_words, limit)
#      60     next
#      61 bs4= BeautifulSoup(html,"html.parser")
# ---> 62 page_data = analyse_page(bs4)
#      63 page_data['html'] = html # this is to add html to the pandas dataframe
#      64 data.append(page_data)
#
# Cell In [1], line 101, in analyse_page(html_soup)
#      93 """
#      94 Searches for instances of keywords
#      95 parameters:
#    (...)
#      98     dict: publishing date, author, and tags archive listings.
#      99 """
#     100 # fecha de publicación
# --> 101 publishing_date = html_soup.find("time").get("datetime")
#     102 author = html_soup.find("span", {'class':'author vcard'})
#     103 if author: author = author.text
#
# AttributeError: 'NoneType' object has no attribute 'get'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   publishing_date  10 non-null     object
#  1   author           10 non-null     object
#  2   tags_archive     10 non-null     object
#  3   title            0 non-null      object
#  4   html             10 non-null     object
# dtypes: object(5)
# memory usage: 528.0+ bytes
