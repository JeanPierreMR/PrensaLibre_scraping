# %%
import pandas as pd

# %%
df = pd.read_csv("info.csv")
df
# Out:
#      Unnamed: 0            publishing_date              author tags_archive  \
# 0             0  2022-09-12T05:00:09-06:00  Redacción C-Studio           []
# 1             1  2022-05-09T05:00:02-06:00                 EFE           []
# 2             2  2022-03-28T13:06:54-06:00                 AFP           []
# 3             3  2022-03-08T09:46:36-06:00                 EFE           []
# 4             4  2021-12-16T00:02:44-06:00    Eugene Kaspersky           []
# ..          ...                        ...                 ...          ...
# 469         469  2014-06-17T00:00:00-06:00       BILLY QUIJADA           []
# 470         470  2014-02-14T00:00:00-06:00    AGENCIA ACAN EFE           []
# 471         471  2013-08-11T00:00:00-06:00       BILLY QUIJADA           []
# 472         472  2013-05-20T00:00:00-06:00       BILLY QUIJADA           []
# 473         473  2001-08-30T00:00:00-06:00                 NaN           []
#
#                                                  title  \
# 0    <h1 class="sart-title">¿Por qué la ciberseguri...
# 1    <h1 class="sart-title">Ciberseguridad personal...
# 2    <h1 class="sart-title">EE. UU. califica de “am...
# 3    <h1 class="sart-title">Google compra la empres...
# 4                                                  NaN
# ..                                                 ...
# 469  <h1 class="sart-title">Piratas informáticos ap...
# 470  <h1 class="sart-title">Panamá invierte US$500 ...
# 471  <h1 class="sart-title">Barreras limitan desarr...
# 472  <h1 class="sart-title">El centinela de la red ...
# 473        <h1 class="sart-title">Breves Globales</h1>
#
#                                                   html
# 0    <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 1    <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 2    <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 3    <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 4    <!doctype html>\n<html lang="es-GT">\n<head>\n...
# ..                                                 ...
# 469  <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 470  <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 471  <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 472  <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 473  <!doctype html>\n<html lang="es-GT">\n<head>\n...
#
# [474 rows x 6 columns]

# %%
# df = df.drop(["html"], axis=1)
df["title"] = df["title"].replace('<h1 class="sart-title">', "")
df
# Out:
#      Unnamed: 0            publishing_date              author tags_archive  \
# 0             0  2022-09-12T05:00:09-06:00  Redacción C-Studio           []
# 1             1  2022-05-09T05:00:02-06:00                 EFE           []
# 2             2  2022-03-28T13:06:54-06:00                 AFP           []
# 3             3  2022-03-08T09:46:36-06:00                 EFE           []
# 4             4  2021-12-16T00:02:44-06:00    Eugene Kaspersky           []
# ..          ...                        ...                 ...          ...
# 469         469  2014-06-17T00:00:00-06:00       BILLY QUIJADA           []
# 470         470  2014-02-14T00:00:00-06:00    AGENCIA ACAN EFE           []
# 471         471  2013-08-11T00:00:00-06:00       BILLY QUIJADA           []
# 472         472  2013-05-20T00:00:00-06:00       BILLY QUIJADA           []
# 473         473  2001-08-30T00:00:00-06:00                 NaN           []
#
#                                                  title  \
# 0    <h1 class="sart-title">¿Por qué la ciberseguri...
# 1    <h1 class="sart-title">Ciberseguridad personal...
# 2    <h1 class="sart-title">EE. UU. califica de “am...
# 3    <h1 class="sart-title">Google compra la empres...
# 4                                                  NaN
# ..                                                 ...
# 469  <h1 class="sart-title">Piratas informáticos ap...
# 470  <h1 class="sart-title">Panamá invierte US$500 ...
# 471  <h1 class="sart-title">Barreras limitan desarr...
# 472  <h1 class="sart-title">El centinela de la red ...
# 473        <h1 class="sart-title">Breves Globales</h1>
#
#                                                   html
# 0    <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 1    <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 2    <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 3    <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 4    <!doctype html>\n<html lang="es-GT">\n<head>\n...
# ..                                                 ...
# 469  <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 470  <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 471  <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 472  <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 473  <!doctype html>\n<html lang="es-GT">\n<head>\n...
#
# [474 rows x 6 columns]

# %%
# df["html"][0]

# %%
df["title"] = df["title"].str.replace('<h1 class="sart-title">', "")
df["title"] = df["title"].str.replace('</h1>', "")
df["title"] = df["title"].str.replace('<h1 class="plus-title">', "")
df["title"] = df["title"].str.replace('\n\t\t\t', "")

df
# Out:
#      Unnamed: 0            publishing_date              author tags_archive  \
# 0             0  2022-09-12T05:00:09-06:00  Redacción C-Studio           []
# 1             1  2022-05-09T05:00:02-06:00                 EFE           []
# 2             2  2022-03-28T13:06:54-06:00                 AFP           []
# 3             3  2022-03-08T09:46:36-06:00                 EFE           []
# 4             4  2021-12-16T00:02:44-06:00    Eugene Kaspersky           []
# ..          ...                        ...                 ...          ...
# 469         469  2014-06-17T00:00:00-06:00       BILLY QUIJADA           []
# 470         470  2014-02-14T00:00:00-06:00    AGENCIA ACAN EFE           []
# 471         471  2013-08-11T00:00:00-06:00       BILLY QUIJADA           []
# 472         472  2013-05-20T00:00:00-06:00       BILLY QUIJADA           []
# 473         473  2001-08-30T00:00:00-06:00                 NaN           []
#
#                                                  title  \
# 0    ¿Por qué la ciberseguridad es más importante h...
# 1    Ciberseguridad personal: consejos para despist...
# 2    EE. UU. califica de “amenaza para la seguridad...
# 3    Google compra la empresa de ciberseguridad Man...
# 4                                                  NaN
# ..                                                 ...
# 469  Piratas informáticos aprovechan temática del M...
# 470  Panamá invierte US$500 millones en modernizaci...
# 471  Barreras limitan desarrollo de ciencia y tecno...
# 472                     El centinela de la red virtual
# 473                                    Breves Globales
#
#                                                   html
# 0    <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 1    <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 2    <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 3    <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 4    <!doctype html>\n<html lang="es-GT">\n<head>\n...
# ..                                                 ...
# 469  <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 470  <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 471  <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 472  <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 473  <!doctype html>\n<html lang="es-GT">\n<head>\n...
#
# [474 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 474 entries, 0 to 473
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       474 non-null    int64
#  1   publishing_date  472 non-null    object
#  2   author           421 non-null    object
#  3   tags_archive     474 non-null    object
#  4   title            450 non-null    object
#  5   html             474 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 22.3+ KB

# %%
df = df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 407 entries, 0 to 472
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       407 non-null    int64
#  1   publishing_date  407 non-null    object
#  2   author           407 non-null    object
#  3   tags_archive     407 non-null    object
#  4   title            407 non-null    object
#  5   html             407 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 22.3+ KB

# %%
df
# Out:
#      Unnamed: 0            publishing_date              author tags_archive  \
# 0             0  2022-09-12T05:00:09-06:00  Redacción C-Studio           []
# 1             1  2022-05-09T05:00:02-06:00                 EFE           []
# 2             2  2022-03-28T13:06:54-06:00                 AFP           []
# 3             3  2022-03-08T09:46:36-06:00                 EFE           []
# 6             6  2021-07-06T08:10:55-06:00      BBC News Mundo           []
# ..          ...                        ...                 ...          ...
# 468         468  2014-08-07T00:00:00-06:00     REDACCIÓN TECNO           []
# 469         469  2014-06-17T00:00:00-06:00       BILLY QUIJADA           []
# 470         470  2014-02-14T00:00:00-06:00    AGENCIA ACAN EFE           []
# 471         471  2013-08-11T00:00:00-06:00       BILLY QUIJADA           []
# 472         472  2013-05-20T00:00:00-06:00       BILLY QUIJADA           []
#
#                                                  title  \
# 0    ¿Por qué la ciberseguridad es más importante h...
# 1    Ciberseguridad personal: consejos para despist...
# 2    EE. UU. califica de “amenaza para la seguridad...
# 3    Google compra la empresa de ciberseguridad Man...
# 6    “Los hackers nos aventajan porque hay poca gen...
# ..                                                 ...
# 468                La seguridad virtual no es un juego
# 469  Piratas informáticos aprovechan temática del M...
# 470  Panamá invierte US$500 millones en modernizaci...
# 471  Barreras limitan desarrollo de ciencia y tecno...
# 472                     El centinela de la red virtual
#
#                                                   html
# 0    <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 1    <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 2    <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 3    <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 6    <!doctype html>\n<html lang="es-GT">\n<head>\n...
# ..                                                 ...
# 468  <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 469  <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 470  <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 471  <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 472  <!doctype html>\n<html lang="es-GT">\n<head>\n...
#
# [407 rows x 6 columns]

# %%
#find prevalence of authors
international_authors = ['BBC News Mundo','BBC Mundo',]
df_national_authors = df.loc[~df['author'].isin(international_authors)]
df_national_authors["author"].value_counts().nlargest(11)
# Out:
# EFE                     25
# Redacción AFP           17
# REDACCIÓN TECNO         12
# Pablo Juárez Andrino    11
# Redacción                8
# Alejandro Ortiz          8
# Katerin Chumil           7
# Andrea Jumique           6
# Urías Gamarro            6
# BILLY QUIJADA            6
# Name: author, dtype: int64

# %%
## Most prevalent words
from collections import Counter
nonoWords = ['el', 'la', 'los', 'las', 'un', 'una', 'unos', 'unas', 'a', 'ante', 'bajo', 'cabe', 'con', 'contra', 'de', 'desde', 'en', 'entre', 'hacia', 'hasta', 'mediante', 'para', 'por', 'según', 'sin', 'so', 'sobre', 'tras', 'versus', 'vía', 'y', 'que', 'del', 'su', 'es', 'más', 'cómo', 'son', 'qué', 'que', 'se', 'no', '<h1', 'class="plus-title">', 'al', 'sus', 'ser', 'está', 'esta', 'te', 'mi']
common = Counter(" ".join(df["title"]).split()).most_common()
commonGood = []

temp = len(common)
for i in range(temp):
    word = common[i][0].lower()
    count = common[i][1]
    # print(common[i][0])
    if word not in nonoWords:
        if count > 10:
            commonGood.append(common[i])
    #     common.remove(word)


print(commonGood)
print(len(commonGood))
# Out:
# [('web', 43), ('seguridad', 40), ('sitio', 31), ('ciberseguridad', 22), ('Guatemala', 20), ('sitios', 18), ('internet', 16), ('ataques', 14), ('red', 13), ('informática', 12), ('informáticos', 11)]
# 11

# %%
tags = []
for i in df['tags_archive']:
    if i != "[]": 
        print(i)
        tags.append(i)
# Out:
# ['CLAVE ECONÓMICA', 'CONTACT CENTER Y BPO', 'ECONOMÍA EN GUATEMALA', 'EXPORTACIÓN DE SERVICIOS', 'LO MÁS DESTACADO', 'LOGÍSTICA Y TRANSPORTE', 'PL PLUS', 'SERVICIOS RELATIVOS A CONOCIMIENTOS', 'TECNOLOGÍAS DE LA INFORMACIÓN']
# ['ESTRATEGIAS', 'EXPLORADORES PLUS', 'MARKETING', 'NEGOCIOS PLUS', 'PL PLUS']
# ['CORONAVIRUS DOS AÑOS', 'ESTUDIO COVID-19', 'EXPLORADORES PLUS']
# ['CIBERATAQUES', 'CLAVE ECONÓMICA', 'CONFLICTO RUSIA-UCRANIA', 'PL PLUS']
# ['PL PLUS', 'RECOMENDACIÓN DE LOS EDITORES', 'THE NEW YORK TIMES COMPANY']
# ['PL PLUS', 'RECOMENDACIÓN DE LOS EDITORES', 'THE NEW YORK TIMES COMPANY']
# ['CORONAVIRUS', 'RECOMENDACIÓN DE LOS EDITORES', 'THE NEW YORK TIMES COMPANY', 'TRABAJO EN CASA']
# ['BUSCADORES', 'NAVEGADORES DE INTERNET', 'TECNOLOGÍA', 'THE NEW YORK TIMES COMPANY']
# ['ABUSO INFANTIL', 'CORONAVIRUS', 'DELITOS SEXUALES', 'PEDOFILIA', 'PL PLUS', 'PLUS IMPRESO', 'RECOMENDACIÓN DE LOS EDITORES']
# ['FACEBOOK', 'PL PLUS', 'RECOMENDACIÓN DE LOS EDITORES', 'THE NEW YORK TIMES COMPANY']
# ['CORONAVIRUS', 'PL PLUS', 'RECOMENDACIÓN DE LOS EDITORES', 'THE NEW YORK TIMES COMPANY']
# ['CONTAMINACIÓN', 'CORONAVIRUS', 'CORONAVIRUS EN GUATEMALA', 'MEDIO AMBIENTE', 'MEDIOAMBIENTE', 'PL PLUS', 'PLUS IMPRESO', 'RECOMENDACIÓN DE LOS EDITORES']
# ['CIBERCRIMEN', 'CIBERSEGURIDAD', 'DATOS', 'PL+']
# ['ESTAFA EN APLICACIÓN', 'ESTAFAS', 'ESTAFAS POR INTERNET', 'PL+', 'RECOMENDACIÓN DE LOS EDITORES', 'THE NEW YORK TIMES COMPANY']
# ['ALEJANDRO GIAMMATTEI', 'CONFLICTIVIDAD', 'DERECHOS HUMANOS', 'EXPLORADORES PLUS']
# ['CORONAVIRUS', 'DESINFONDEMIA', 'PL PLUS', 'PLUS IMPRESO', 'RECOMENDACIÓN DE LOS EDITORES']
# ['ABUSO INFANTIL', 'CORONAVIRUS', 'DELITOS SEXUALES', 'PEDOFILIA', 'PL PLUS', 'PLUS IMPRESO', 'RECOMENDACIÓN DE LOS EDITORES']

# %%
df.loc[df['tags_archive'].isin(tags)]
# Out:
#      Unnamed: 0            publishing_date  \
# 40           40  2022-10-07T05:00:41-06:00
# 78           78  2022-04-01T05:00:53-06:00
# 81           81  2022-03-16T05:00:55-06:00
# 85           85  2022-03-01T05:00:46-06:00
# 95           95  2022-01-06T18:00:32-06:00
# 151         151  2022-06-04T05:00:57-06:00
# 159         159  2021-09-17T12:02:14-06:00
# 162         162  2021-04-15T18:05:51-06:00
# 166         166  2020-06-25T05:00:05-06:00
# 318         318  2021-09-24T14:21:16-06:00
# 320         320  2021-09-03T12:11:44-06:00
# 328         328  2020-08-19T06:00:20-06:00
# 377         377  2021-04-28T05:00:46-06:00
# 401         401  2022-02-25T09:30:41-06:00
# 404         404  2021-04-29T05:00:40-06:00
# 411         411  2020-07-02T05:00:39-06:00
# 412         412  2020-06-25T05:00:05-06:00
#
#                                                 author  \
# 40                                       Agustín Ortiz
# 78   Enrique Canahui y Estuardo Gasparico Marroquín...
# 81                               José Pablo del Águila
# 85         Elder Interiano, Especial para Prensa Libre
# 95   Ryan Mac y Kashmir Hill/©2021 The New York Tim...
# 151  Steven Lee Myers y Stuart A. Thompson/©2022 Th...
# 159  Tara Parker-Pope. C. The New York Times Compan...
# 162    Brian X. Chen c.2021 The New York Times Company
# 166                                    Brenda Martínez
# 318  Ryan Mac y Sheera Frenkel. C. The New York Tim...
# 320    Pam Belluck. c. The New York Times Company 2021
# 328                                    Brenda Martínez
# 377                                     Katerin Chumil
# 401      Kevin Roose c.2022 The New York Times Company
# 404                                     Sergio Morales
# 411                                    Brenda Martínez
# 412                                    Brenda Martínez
#
#                                           tags_archive  \
# 40   ['CLAVE ECONÓMICA', 'CONTACT CENTER Y BPO', 'E...
# 78   ['ESTRATEGIAS', 'EXPLORADORES PLUS', 'MARKETIN...
# 81   ['CORONAVIRUS DOS AÑOS', 'ESTUDIO COVID-19', '...
# 85   ['CIBERATAQUES', 'CLAVE ECONÓMICA', 'CONFLICTO...
# 95   ['PL PLUS', 'RECOMENDACIÓN DE LOS EDITORES', '...
# 151  ['PL PLUS', 'RECOMENDACIÓN DE LOS EDITORES', '...
# 159  ['CORONAVIRUS', 'RECOMENDACIÓN DE LOS EDITORES...
# 162  ['BUSCADORES', 'NAVEGADORES DE INTERNET', 'TEC...
# 166  ['ABUSO INFANTIL', 'CORONAVIRUS', 'DELITOS SEX...
# 318  ['FACEBOOK', 'PL PLUS', 'RECOMENDACIÓN DE LOS ...
# 320  ['CORONAVIRUS', 'PL PLUS', 'RECOMENDACIÓN DE L...
# 328  ['CONTAMINACIÓN', 'CORONAVIRUS', 'CORONAVIRUS ...
# 377  ['CIBERCRIMEN', 'CIBERSEGURIDAD', 'DATOS', 'PL+']
# 401  ['ESTAFA EN APLICACIÓN', 'ESTAFAS', 'ESTAFAS P...
# 404  ['ALEJANDRO GIAMMATTEI', 'CONFLICTIVIDAD', 'DE...
# 411  ['CORONAVIRUS', 'DESINFONDEMIA', 'PL PLUS', 'P...
# 412  ['ABUSO INFANTIL', 'CORONAVIRUS', 'DELITOS SEX...
#
#                                                  title  \
# 40   ¿Piensa en exportar servicios? Estos son los c...
# 78   ¿En línea o en tienda física? Las categorías g...
# 81   En pandemia una de cada cuatro personas trabaj...
# 85   Conflicto Rusia-Ucrania: ¿Cuáles son los riesg...
# 95   ¿Se están usando los Apple AirTags para seguir...
# 151  Las ideas racistas que saltan de los márgenes ...
# 159  Seis preguntas y respuestas sobre el coronavir...
# 162  Si te preocupa la privacidad, es momento de pr...
# 166  Depredadores sexuales infantiles acechan en la...
# 318  Este es el plan de Facebook para defender su i...
# 320  Estudio señala que pacientes con covid-19 podr...
# 328  Mascarillas y guantes en los vertederos de bas...
# 377  Cibercrimen: ¿están preparadas las autoridades...
# 401  Las aplicaciones de citas, el nuevo blanco de ...
# 404  Así funciona la Comisión Presidencial por la P...
# 411  Alto: Se necesita vacuna para la “desinfondemi...
# 412  Depredadores sexuales infantiles acechan en la...
#
#                                                   html
# 40   <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 78   <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 81   <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 85   <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 95   <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 151  <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 159  <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 162  <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 166  <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 318  <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 320  <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 328  <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 377  <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 401  <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 404  <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 411  <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 412  <!doctype html>\n<html lang="es-GT">\n<head>\n...

# %%
war_df=df.loc['title'].str.find(sub)
# Out:
#      Unnamed: 0            publishing_date              author tags_archive  \
# 0             0  2022-09-12T05:00:09-06:00  Redacción C-Studio           []
# 1             1  2022-05-09T05:00:02-06:00                 EFE           []
# 2             2  2022-03-28T13:06:54-06:00                 AFP           []
# 3             3  2022-03-08T09:46:36-06:00                 EFE           []
# 6             6  2021-07-06T08:10:55-06:00      BBC News Mundo           []
# ..          ...                        ...                 ...          ...
# 468         468  2014-08-07T00:00:00-06:00     REDACCIÓN TECNO           []
# 469         469  2014-06-17T00:00:00-06:00       BILLY QUIJADA           []
# 470         470  2014-02-14T00:00:00-06:00    AGENCIA ACAN EFE           []
# 471         471  2013-08-11T00:00:00-06:00       BILLY QUIJADA           []
# 472         472  2013-05-20T00:00:00-06:00       BILLY QUIJADA           []
#
#                                                  title  \
# 0    ¿Por qué la ciberseguridad es más importante h...
# 1    Ciberseguridad personal: consejos para despist...
# 2    EE. UU. califica de “amenaza para la seguridad...
# 3    Google compra la empresa de ciberseguridad Man...
# 6    “Los hackers nos aventajan porque hay poca gen...
# ..                                                 ...
# 468                La seguridad virtual no es un juego
# 469  Piratas informáticos aprovechan temática del M...
# 470  Panamá invierte US$500 millones en modernizaci...
# 471  Barreras limitan desarrollo de ciencia y tecno...
# 472                     El centinela de la red virtual
#
#                                                   html
# 0    <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 1    <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 2    <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 3    <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 6    <!doctype html>\n<html lang="es-GT">\n<head>\n...
# ..                                                 ...
# 468  <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 469  <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 470  <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 471  <!doctype html>\n<html lang="es-GT">\n<head>\n...
# 472  <!doctype html>\n<html lang="es-GT">\n<head>\n...
#
# [407 rows x 6 columns]

# %%
# for i in df["title"]:
#     if "web" in i or "":
# Out:
#   Cell In [316], line 2
#     if "web" in i or "":
#                         ^
# SyntaxError: incomplete input
